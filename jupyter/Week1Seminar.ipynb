# %% [markdown]
# # Week 1 Seminar
#
# A/B experiment analysis

# %%
import glob
from collections import namedtuple

import pandas as pd
import numpy as np
import scipy.stats as ss

import matplotlib.pyplot as plt

pd.set_option("display.precision", 3)

# %matplotlib inline

# %%
experiment = "PERSONALIZED"
# Out:
# 5

# %%
data = pd.concat([
    pd.read_json(data_path, lines=True)
    for data_path
    in glob.glob("/tmp/log/data.json")
])

data["treatment"] = data["experiments"].map(lambda experiments: experiments[experiment])

# %%
data.groupby("treatment").count()

# %% [markdown]
# ## Visualize sessions

# %%
Session = namedtuple("Session", ["timestamp", "tracks", "time", "latency"])

def sessionize(user_data):
    sessions = []
    session = None
    for _, row in user_data.sort_values("timestamp").iterrows():
        if session is None:
            session = Session(row["timestamp"], 0, 0, 0)
        
        session = session._replace(
            tracks = session.tracks + 1, 
            time = session.time + row["time"],
            latency = session.latency + row["latency"] * 1000,
        )
        
        if row["message"] == "last":
            sessions.append(session._asdict())
            session = None
    return sessions

# %%
sessions = (
    data
    .groupby(["user", "treatment"])
    .apply(sessionize)
    .explode()
    .apply(pd.Series)
)

# %%
figure, ax = plt.subplots(figsize=(15, 5))
for treatment, treatment_sessions in sessions.groupby("treatment"):
    reindexed_treatment_sessions = treatment_sessions.sort_values("timestamp").reset_index()
    ax.plot(reindexed_treatment_sessions.index, reindexed_treatment_sessions["tracks"], label=treatment)
ax.legend()
pass

# %%
figure, ax = plt.subplots(figsize=(15, 5))
for treatment, treatment_sessions in sessions.groupby("treatment"):
    reindexed_treatment_sessions = treatment_sessions.sort_values("timestamp").reset_index()
    ax.plot(reindexed_treatment_sessions.index, reindexed_treatment_sessions["time"], label=treatment)
ax.legend()
pass

# %% [markdown]
# ## Analyze the experiment

# %%
user_level_data = (
  sessions
    .reset_index()
    .groupby(["user", "treatment"])
    .agg(
        {
            "timestamp": "count",
            "tracks": "sum",
            "time": "sum",
            "latency": "sum"
        }
    )
)

user_level_data["sessions"] = user_level_data["timestamp"]
user_level_data["mean_request_latency"] = user_level_data["latency"] / user_level_data["tracks"]
user_level_data["mean_tracks_per_session"] = user_level_data["tracks"] / user_level_data["sessions"]
user_level_data["mean_time_per_session"] = user_level_data["time"] / user_level_data["sessions"]

metrics = [
    "time", 
    "sessions", 
    "mean_request_latency", 
    "mean_tracks_per_session", 
    "mean_time_per_session"
]

user_level_metrics = user_level_data[metrics].copy().reset_index()

# %%
treatment_level_metrics = (
    user_level_metrics
    .groupby("treatment")[metrics]
    .agg(["count", "mean", "var"])
)

# %%
def dof(n_0, n_1, s2_0, s2_1):
    numerator = (s2_0 / n_0 + s2_1 / n_1) * (s2_0 / n_0 + s2_1 / n_1)
    denominator = s2_0 * s2_0 / n_0 / n_0 / (n_0 - 1) + s2_1 * s2_1 / n_1 / n_1 / (n_1 - 1)
    return numerator / denominator


def ci(n_0, n_1, s2_0, s2_1, alpha=0.05):
    return ss.t.ppf(1 - alpha/2, dof(n_0, n_1, s2_0, s2_1)) * np.sqrt(s2_0 / n_0 + s2_1 / n_1)


effects = []

control = [data for treatment, data in treatment_level_metrics.iterrows() if treatment == "C"][0]

for treatment, row in treatment_level_metrics.iterrows():
    if treatment == "C":
        continue
    
    for metric in metrics:
        control_mean = control[metric]["mean"]
        treatment_mean = row[metric]["mean"]
        
        effect = treatment_mean - control_mean
        conf_int = ci(
            control[metric]["count"],
            row[metric]["count"],
            control[metric]["var"],
            row[metric]["var"],
        )
        effects.append({
            "treatment": treatment,
            "metric": metric,
            "control_mean": control_mean,
            "treatment_mean": treatment_mean,
            "effect": effect / control_mean * 100,
            "lower": (effect - conf_int) / control_mean * 100,
            "upper": (effect + conf_int) / control_mean * 100,
            "significant": (effect + conf_int) * (effect - conf_int) > 0
        })

# %%
def color(value):
    return 'color:red;' if value < 0 else 'color:green;'

def background(value):
    return 'color:white;background-color:green' if value else 'color:white;background-color:red'
        

(
    pd.DataFrame(effects)[[
        "treatment", 
        "metric",
        "effect", 
        "upper", 
        "lower", 
        "control_mean", 
        "treatment_mean",
        "significant"
    ]]
    .sort_values(["metric", "treatment"], ascending=False)
    .style
    .applymap(color, subset=["effect", "upper", "lower"])
    .applymap(background, subset=["significant"])
)
# Out:
# <style type="text/css">
# #T_9acc0_row0_col2, #T_9acc0_row0_col3, #T_9acc0_row0_col4, #T_9acc0_row1_col3, #T_9acc0_row2_col2, #T_9acc0_row2_col3, #T_9acc0_row2_col4, #T_9acc0_row3_col2, #T_9acc0_row3_col3, #T_9acc0_row3_col4 {
#   color: green;
# }
# #T_9acc0_row0_col7, #T_9acc0_row2_col7, #T_9acc0_row3_col7, #T_9acc0_row4_col7 {
#   color: white;
#   background-color: green;
# }
# #T_9acc0_row1_col2, #T_9acc0_row1_col4, #T_9acc0_row4_col2, #T_9acc0_row4_col3, #T_9acc0_row4_col4 {
#   color: red;
# }
# #T_9acc0_row1_col7 {
#   color: white;
#   background-color: red;
# }
# </style>
# <table id="T_9acc0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >treatment</th>
#       <th class="col_heading level0 col1" >metric</th>
#       <th class="col_heading level0 col2" >effect</th>
#       <th class="col_heading level0 col3" >upper</th>
#       <th class="col_heading level0 col4" >lower</th>
#       <th class="col_heading level0 col5" >control_mean</th>
#       <th class="col_heading level0 col6" >treatment_mean</th>
#       <th class="col_heading level0 col7" >significant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9acc0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9acc0_row0_col0" class="data row0 col0" >T1</td>
#       <td id="T_9acc0_row0_col1" class="data row0 col1" >time</td>
#       <td id="T_9acc0_row0_col2" class="data row0 col2" >61.784</td>
#       <td id="T_9acc0_row0_col3" class="data row0 col3" >78.302</td>
#       <td id="T_9acc0_row0_col4" class="data row0 col4" >45.266</td>
#       <td id="T_9acc0_row0_col5" class="data row0 col5" >4.955</td>
#       <td id="T_9acc0_row0_col6" class="data row0 col6" >8.016</td>
#       <td id="T_9acc0_row0_col7" class="data row0 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9acc0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9acc0_row1_col0" class="data row1 col0" >T1</td>
#       <td id="T_9acc0_row1_col1" class="data row1 col1" >sessions</td>
#       <td id="T_9acc0_row1_col2" class="data row1 col2" >-0.500</td>
#       <td id="T_9acc0_row1_col3" class="data row1 col3" >2.138</td>
#       <td id="T_9acc0_row1_col4" class="data row1 col4" >-3.139</td>
#       <td id="T_9acc0_row1_col5" class="data row1 col5" >1.213</td>
#       <td id="T_9acc0_row1_col6" class="data row1 col6" >1.206</td>
#       <td id="T_9acc0_row1_col7" class="data row1 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9acc0_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_9acc0_row2_col0" class="data row2 col0" >T1</td>
#       <td id="T_9acc0_row2_col1" class="data row2 col1" >mean_tracks_per_session</td>
#       <td id="T_9acc0_row2_col2" class="data row2 col2" >27.998</td>
#       <td id="T_9acc0_row2_col3" class="data row2 col3" >35.366</td>
#       <td id="T_9acc0_row2_col4" class="data row2 col4" >20.629</td>
#       <td id="T_9acc0_row2_col5" class="data row2 col5" >9.044</td>
#       <td id="T_9acc0_row2_col6" class="data row2 col6" >11.576</td>
#       <td id="T_9acc0_row2_col7" class="data row2 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9acc0_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_9acc0_row3_col0" class="data row3 col0" >T1</td>
#       <td id="T_9acc0_row3_col1" class="data row3 col1" >mean_time_per_session</td>
#       <td id="T_9acc0_row3_col2" class="data row3 col2" >63.294</td>
#       <td id="T_9acc0_row3_col3" class="data row3 col3" >79.595</td>
#       <td id="T_9acc0_row3_col4" class="data row3 col4" >46.994</td>
#       <td id="T_9acc0_row3_col5" class="data row3 col5" >4.040</td>
#       <td id="T_9acc0_row3_col6" class="data row3 col6" >6.598</td>
#       <td id="T_9acc0_row3_col7" class="data row3 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9acc0_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_9acc0_row4_col0" class="data row4 col0" >T1</td>
#       <td id="T_9acc0_row4_col1" class="data row4 col1" >mean_request_latency</td>
#       <td id="T_9acc0_row4_col2" class="data row4 col2" >-8.525</td>
#       <td id="T_9acc0_row4_col3" class="data row4 col3" >-5.383</td>
#       <td id="T_9acc0_row4_col4" class="data row4 col4" >-11.666</td>
#       <td id="T_9acc0_row4_col5" class="data row4 col5" >0.472</td>
#       <td id="T_9acc0_row4_col6" class="data row4 col6" >0.431</td>
#       <td id="T_9acc0_row4_col7" class="data row4 col7" >True</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Out:
# <style type="text/css">
# #T_727df_row0_col2, #T_727df_row0_col3, #T_727df_row0_col4, #T_727df_row1_col2, #T_727df_row1_col3, #T_727df_row1_col4, #T_727df_row2_col2, #T_727df_row2_col3, #T_727df_row2_col4, #T_727df_row3_col2, #T_727df_row3_col3, #T_727df_row3_col4, #T_727df_row4_col3, #T_727df_row5_col2, #T_727df_row5_col3, #T_727df_row5_col4, #T_727df_row12_col2, #T_727df_row12_col3, #T_727df_row12_col4, #T_727df_row13_col2, #T_727df_row13_col3, #T_727df_row13_col4, #T_727df_row14_col2, #T_727df_row14_col3, #T_727df_row14_col4, #T_727df_row15_col2, #T_727df_row15_col3, #T_727df_row15_col4, #T_727df_row16_col2, #T_727df_row16_col3, #T_727df_row17_col2, #T_727df_row17_col3, #T_727df_row17_col4, #T_727df_row18_col2, #T_727df_row18_col3, #T_727df_row18_col4, #T_727df_row19_col2, #T_727df_row19_col3, #T_727df_row19_col4, #T_727df_row20_col2, #T_727df_row20_col3, #T_727df_row20_col4, #T_727df_row21_col2, #T_727df_row21_col3, #T_727df_row21_col4, #T_727df_row22_col2, #T_727df_row22_col3, #T_727df_row23_col2, #T_727df_row23_col3, #T_727df_row23_col4, #T_727df_row24_col2, #T_727df_row24_col3, #T_727df_row24_col4, #T_727df_row25_col2, #T_727df_row25_col3, #T_727df_row25_col4, #T_727df_row26_col2, #T_727df_row26_col3, #T_727df_row26_col4, #T_727df_row27_col2, #T_727df_row27_col3, #T_727df_row27_col4, #T_727df_row28_col3, #T_727df_row29_col2, #T_727df_row29_col3, #T_727df_row29_col4 {
#   color: green;
# }
# #T_727df_row0_col7, #T_727df_row1_col7, #T_727df_row2_col7, #T_727df_row3_col7, #T_727df_row5_col7, #T_727df_row6_col7, #T_727df_row7_col7, #T_727df_row8_col7, #T_727df_row9_col7, #T_727df_row10_col7, #T_727df_row11_col7, #T_727df_row12_col7, #T_727df_row13_col7, #T_727df_row14_col7, #T_727df_row15_col7, #T_727df_row17_col7, #T_727df_row18_col7, #T_727df_row19_col7, #T_727df_row20_col7, #T_727df_row21_col7, #T_727df_row23_col7, #T_727df_row24_col7, #T_727df_row25_col7, #T_727df_row26_col7, #T_727df_row27_col7, #T_727df_row29_col7 {
#   color: white;
#   background-color: green;
# }
# #T_727df_row4_col2, #T_727df_row4_col4, #T_727df_row6_col2, #T_727df_row6_col3, #T_727df_row6_col4, #T_727df_row7_col2, #T_727df_row7_col3, #T_727df_row7_col4, #T_727df_row8_col2, #T_727df_row8_col3, #T_727df_row8_col4, #T_727df_row9_col2, #T_727df_row9_col3, #T_727df_row9_col4, #T_727df_row10_col2, #T_727df_row10_col3, #T_727df_row10_col4, #T_727df_row11_col2, #T_727df_row11_col3, #T_727df_row11_col4, #T_727df_row16_col4, #T_727df_row22_col4, #T_727df_row28_col2, #T_727df_row28_col4 {
#   color: red;
# }
# #T_727df_row4_col7, #T_727df_row16_col7, #T_727df_row22_col7, #T_727df_row28_col7 {
#   color: white;
#   background-color: red;
# }
# </style>
# <table id="T_727df_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >treatment</th>
#       <th class="col_heading level0 col1" >metric</th>
#       <th class="col_heading level0 col2" >effect</th>
#       <th class="col_heading level0 col3" >upper</th>
#       <th class="col_heading level0 col4" >lower</th>
#       <th class="col_heading level0 col5" >control_mean</th>
#       <th class="col_heading level0 col6" >treatment_mean</th>
#       <th class="col_heading level0 col7" >significant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_727df_level0_row0" class="row_heading level0 row0" >25</th>
#       <td id="T_727df_row0_col0" class="data row0 col0" >T6</td>
#       <td id="T_727df_row0_col1" class="data row0 col1" >time</td>
#       <td id="T_727df_row0_col2" class="data row0 col2" >81.326</td>
#       <td id="T_727df_row0_col3" class="data row0 col3" >106.201</td>
#       <td id="T_727df_row0_col4" class="data row0 col4" >56.451</td>
#       <td id="T_727df_row0_col5" class="data row0 col5" >2.193</td>
#       <td id="T_727df_row0_col6" class="data row0 col6" >3.977</td>
#       <td id="T_727df_row0_col7" class="data row0 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_727df_level0_row1" class="row_heading level0 row1" >20</th>
#       <td id="T_727df_row1_col0" class="data row1 col0" >T5</td>
#       <td id="T_727df_row1_col1" class="data row1 col1" >time</td>
#       <td id="T_727df_row1_col2" class="data row1 col2" >47.494</td>
#       <td id="T_727df_row1_col3" class="data row1 col3" >69.357</td>
#       <td id="T_727df_row1_col4" class="data row1 col4" >25.631</td>
#       <td id="T_727df_row1_col5" class="data row1 col5" >2.193</td>
#       <td id="T_727df_row1_col6" class="data row1 col6" >3.235</td>
#       <td id="T_727df_row1_col7" class="data row1 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_727df_level0_row2" class="row_heading level0 row2" >15</th>
#       <td id="T_727df_row2_col0" class="data row2 col0" >T4</td>
#       <td id="T_727df_row2_col1" class="data row2 col1" >time</td>
#       <td id="T_727df_row2_col2" class="data row2 col2" >96.361</td>
#       <td id="T_727df_row2_col3" class="data row2 col3" >128.751</td>
#       <td id="T_727df_row2_col4" class="data row2 col4" >63.970</td>
#       <td id="T_727df_row2_col5" class="data row2 col5" >2.193</td>
#       <td id="T_727df_row2_col6" class="data row2 col6" >4.307</td>
#       <td id="T_727df_row2_col7" class="data row2 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_727df_level0_row3" class="row_heading level0 row3" >10</th>
#       <td id="T_727df_row3_col0" class="data row3 col0" >T3</td>
#       <td id="T_727df_row3_col1" class="data row3 col1" >time</td>
#       <td id="T_727df_row3_col2" class="data row3 col2" >95.916</td>
#       <td id="T_727df_row3_col3" class="data row3 col3" >118.982</td>
#       <td id="T_727df_row3_col4" class="data row3 col4" >72.850</td>
#       <td id="T_727df_row3_col5" class="data row3 col5" >2.193</td>
#       <td id="T_727df_row3_col6" class="data row3 col6" >4.297</td>
#       <td id="T_727df_row3_col7" class="data row3 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_727df_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_727df_row4_col0" class="data row4 col0" >T2</td>
#       <td id="T_727df_row4_col1" class="data row4 col1" >time</td>
#       <td id="T_727df_row4_col2" class="data row4 col2" >-3.699</td>
#       <td id="T_727df_row4_col3" class="data row4 col3" >9.926</td>
#       <td id="T_727df_row4_col4" class="data row4 col4" >-17.324</td>
#       <td id="T_727df_row4_col5" class="data row4 col5" >2.193</td>
#       <td id="T_727df_row4_col6" class="data row4 col6" >2.112</td>
#       <td id="T_727df_row4_col7" class="data row4 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_727df_level0_row5" class="row_heading level0 row5" >0</th>
#       <td id="T_727df_row5_col0" class="data row5 col0" >T1</td>
#       <td id="T_727df_row5_col1" class="data row5 col1" >time</td>
#       <td id="T_727df_row5_col2" class="data row5 col2" >53.609</td>
#       <td id="T_727df_row5_col3" class="data row5 col3" >67.475</td>
#       <td id="T_727df_row5_col4" class="data row5 col4" >39.744</td>
#       <td id="T_727df_row5_col5" class="data row5 col5" >2.193</td>
#       <td id="T_727df_row5_col6" class="data row5 col6" >3.369</td>
#       <td id="T_727df_row5_col7" class="data row5 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_727df_level0_row6" class="row_heading level0 row6" >26</th>
#       <td id="T_727df_row6_col0" class="data row6 col0" >T6</td>
#       <td id="T_727df_row6_col1" class="data row6 col1" >sessions</td>
#       <td id="T_727df_row6_col2" class="data row6 col2" >-5.686</td>
#       <td id="T_727df_row6_col3" class="data row6 col3" >-0.154</td>
#       <td id="T_727df_row6_col4" class="data row6 col4" >-11.218</td>
#       <td id="T_727df_row6_col5" class="data row6 col5" >1.178</td>
#       <td id="T_727df_row6_col6" class="data row6 col6" >1.111</td>
#       <td id="T_727df_row6_col7" class="data row6 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_727df_level0_row7" class="row_heading level0 row7" >21</th>
#       <td id="T_727df_row7_col0" class="data row7 col0" >T5</td>
#       <td id="T_727df_row7_col1" class="data row7 col1" >sessions</td>
#       <td id="T_727df_row7_col2" class="data row7 col2" >-5.830</td>
#       <td id="T_727df_row7_co
